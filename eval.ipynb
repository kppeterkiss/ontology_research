# %%
import pandas as pd

# %%
res_df=pd.read_json("pipeline_performance_log.jsonl", lines=True)

# %%
counts=res_df['mention'].value_counts()

# %%
type(counts)
# Out:
# pandas.Series

# %%
counts=counts.to_dict()

# %%
# Out:
# {'abdomen': 2,
#  'grafting': 2,
#  'hemolymph': 2,
#  'pesticide': 2,
#  'pheromone': 2,
#  'pupa': 2,
#  'sacbrood': 2,
#  'thorax': 2,
#  'alarm': 2,
#  'larva': 2,
#  'amitraz': 2,
#  'hormone': 2,
#  'amplitude': 2,
#  'antenna': 2,
#  'inspection': 2,
#  'proboscis': 2,
#  'worker': 2,
#  'apiary': 2,
#  'colony': 2,
#  'flight': 2,
#  'foraging': 2,
#  'frame': 2,
#  'frequency': 2,
#  'humidity': 2,
#  'iot': 2,
#  'nectar': 2,
#  'temperature': 2,
#  'weight': 2,
#  'apis': 2,
#  'arduino': 2,
#  'loadcell': 2,
#  'voltage': 2,
#  'battery': 2,
#  'bee': 2,
#  'beehive': 2,
#  'microcontroller': 2,
#  'calibration': 2,
#  'entrance': 2,
#  'video': 2,
#  'gps': 2,
#  'rainfall': 2,
#  'thermoregulation': 2,
#  'image': 2,
#  'logger': 2,
#  'measurement': 2,
#  'observation': 2,
#  'noise': 2,
#  'sensor': 2,
#  'spectrogram': 2,
#  'thymol': 2,
#  'acoustic amplitude': 2,
#  'audio spectrogram image': 2,
#  'acoustic analysis': 1,
#  'acoustic and vibration signal': 1,
# ...
