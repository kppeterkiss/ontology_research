# %%
import pandas as pd

# %%
pd.read_json("pipeline_performance_log.jsonl")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.read_json("pipeline_performance_log.jsonl")
#
# File ~/PycharmProjects/ontology_research/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:853, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     851     return json_reader
#     852 else:
# --> 853     return json_reader.read()
#
# File ~/PycharmProjects/ontology_research/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:989, in JsonReader.read(self)
#     987         obj = self._read_pyarrow()
#     988     elif self.engine == "ujson":
# --> 989         obj = self._read_ujson()
#     991 return obj
#
# ...
